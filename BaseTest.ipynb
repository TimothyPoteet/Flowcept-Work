# %%
from flowcept import Flowcept
from workflow import Workflow
from qa_chain import QAChain

# %%
workflow_id = Workflow.run()
# Out:
# 8
# Workflow_id=98efb6be-8c9f-4a5e-9e3b-a231c19e12fd

# %%
qa = QAChain().build(workflow_id)
# Out:
# /home/tpoteet/ornl/flowcept_tests/qa_chain.py:42: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(

# %%
qa.tasks[0]
# Out:
# {'task_id': '1748549489.507195',
#  'activity_id': 'sum_one',
#  'workflow_id': '98efb6be-8c9f-4a5e-9e3b-a231c19e12fd',
#  'campaign_id': '85f3efc7-7e45-4da5-a409-d22f2b2589aa',
#  'used': {'arg_0': 3},
#  'started_at': datetime.datetime(2025, 5, 29, 20, 11, 29, 507000),
#  'telemetry_at_start': {'cpu': {'times_avg': {'user': 1615.29,
#     'nice': 28.59,
#     'system': 1107.44,
#     'idle': 283301.41,
#     'iowait': 204.19,
#     'irq': 0.0,
#     'softirq': 209.42,
#     'steal': 0.0,
#     'guest': 0.0,
#     'guest_nice': 0.0},
#    'percent_all': 10.6,
#    'frequency': 2419.199,
#    'times_per_cpu': [{'user': 219.62,
#      'nice': 12.4,
#      'system': 152.86,
#      'idle': 35316.03,
#      'iowait': 33.72,
#      'irq': 0.0,
#      'softirq': 106.66,
#      'steal': 0.0,
#      'guest': 0.0,
#      'guest_nice': 0.0},
#     {'user': 195.4,
#      'nice': 0.04,
#      'system': 134.11,
#      'idle': 35420.42,
#      'iowait': 40.27,
#      'irq': 0.0,
# ...

# %%
r = qa.ask('how many tasks?')
# Out:
# /home/tpoteet/ornl/flowcept_tests/qa_chain.py:25: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = self.qa_chain({"query": f"{context}. {query}"})
# Q: how many tasks?
# There are 2 tasks.
# ---------------- I took 4.8 s to answer this.

# %%
r = qa.ask('what is the average task duration?')
# Out:
# Q: what is the average task duration?
# I don't know.
# ---------------- I took 4.0 s to answer this.

# %%
r = qa.ask('what is the first task?')
# Out:
# Q: what is the first task?
# The first task is the one with the earliest `started_at` time.
#
# Looking at the provided data, the task with the earliest `started_at` time is the one with `task_id`: '1748464377.1565428'.
# ---------------- I took 3.6 s to answer this.

# %%
r = qa.ask("give me the python code that plots the tasks' start time through time")
# Out:
# Q: give me the python code that plots the tasks' start time through time
# ```python
# import matplotlib.pyplot as plt
# import datetime
#
# # Assuming your data is stored in a list of dictionaries called 'tasks'
# tasks = [...]  # Replace with your actual data
#
# # Extract start times and durations
# start_times = [task['started_at'] for task in tasks]
# durations = [(task['ended_at'] - task['started_at']).total_seconds() for task in tasks]
#
# # Convert start times to matplotlib datetime format
# start_times_mpl = [plt.date2num(time) for time in start_times]
#
# # Plot tasks
# plt.figure(figsize=(10, 6))
# plt.hlines(range(len(tasks)), start_times_mpl, [start_time + duration for start_time, duration in zip(start_times_mpl, durations)], color='blue')
# plt.xlabel('Time')
# plt.ylabel('Task ID')
# plt.title('Task Execution Timeline')
# plt.yticks(range(len(tasks)), [task['task_id'] for task in tasks])
# plt.show()
# ```
#
# **Explanation:**
#
# 1. **Data Extraction:**
# ...

# %%
import matplotlib.pyplot as plt
import datetime

# Assuming your data is stored in a list of dictionaries called 'tasks'
  # Replace with your actual data

# Extract start times and durations
start_times = [task['started_at'] for task in tasks]
durations = [(task['ended_at'] - task['started_at']).total_seconds() for task in tasks]

# Convert start times to matplotlib datetime format
start_times_mpl = [plt.date2num(time) for time in start_times]

# Plot tasks
plt.figure(figsize=(10, 6))
plt.hlines(range(len(tasks)), start_times_mpl, [start_time + duration for start_time, duration in zip(start_times_mpl, durations)], color='blue')
plt.xlabel('Time')
plt.ylabel('Task ID')
plt.title('Task Execution Timeline')
plt.yticks(range(len(tasks)), [task['task_id'] for task in tasks])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 12
#       9 durations = [(task['ended_at'] - task['started_at']).total_seconds() for task in tasks]
#      11 # Convert start times to matplotlib datetime format
# ---> 12 start_times_mpl = [plt.date2num(time) for time in start_times]
#      14 # Plot tasks
#      15 plt.figure(figsize=(10, 6))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'date2num'

# %%
r = qa.ask('what is the mean task duration?', context=None)
# Out:
# Q: what is the mean task duration?
# I don't know.
# ---------------- I took 3.6 s to answer this.

# %%
r = qa.ask('what is the first task?', context=None)
# Out:
# Q: what is the first task?
# The first task is the one with the earliest `started_at` time.
#
# Looking at the provided data, the task with the earliest `started_at` time is the one with `task_id`: '1748464377.1565428'.
# ---------------- I took 5.5 s to answer this.

# %%
r = qa.ask('What is the first task, and what does it do?', context = 'it is not mult_two')
# Out:
# Q: What is the first task, and what does it do?
# The first task is `sum_one`.
#
# It takes an input `arg_0` and adds 1 to it.
#
# In the provided example, `arg_0` is 3, so the output of `sum_one` would be 4.
# ---------------- I took 4.5 s to answer this.

# %%
r = qa.ask('What is the second task, and what does it do?', context = 'none')
# Out:
# Q: What is the second task, and what does it do?
# The second task is `sum_one`. It takes an input `arg_0` and adds 1 to it.
#
# For example, if `arg_0` is 3, the task will output 4.
# ---------------- I took 3.7 s to answer this.
